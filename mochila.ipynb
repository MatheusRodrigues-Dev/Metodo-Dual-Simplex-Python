# %%
from classes.ClassMochileiro import KnapsackSolver

# %%
# Objetos do exemplo
objetos = [
    "Barra de cereal",
    "Casaco",
    "Tênis",
    "Celular",
    "Água",
    "Protetor solar",
    "Protetor labial",
    "Garrafas de oxigênio",
    "Máquina fotográfica"
]

utilidade = [6, 7, 3, 2, 9, 5, 2, 10, 6]
peso_gramas = [200, 400, 400, 100, 1000, 200, 30, 3000, 500]
capacidade_total = 5000  # 5 kg em gramas

solver = KnapsackSolver(utilidade, peso_gramas, capacidade_total)
res = solver.solve()
solver.print_model_equations()

print("\n=== Solução para o Exemplo (Mochila) ===")
print(f"Status: {res['status']}")
print(f"Capacidade utilizada: {res['total_weight']} g de {capacidade_total} g")
print(f"Utilidade total: {res['total_value']}")

print("\nItens escolhidos:")
for i in res['selected_items']:
    print(f"  {objetos[i]} (utilidade = {utilidade[i]}, peso = {peso_gramas[i]} g)")
# Out:
# Função objetivo:
# max z = 6·x0 + 7·x1 + 3·x2 + 2·x3 + 9·x4 + 5·x5 + 2·x6 + 10·x7 + 6·x8
#
# Restrição de capacidade:
#       200·x0 + 400·x1 + 400·x2 + 100·x3 + 1000·x4 + 200·x5 + 30·x6 + 3000·x7 + 500·x8 ≤ 5000
#
# Variáveis de decisão:
#       x0 ∈ {0, 1}
#       x1 ∈ {0, 1}
#       x2 ∈ {0, 1}
#       x3 ∈ {0, 1}
#       x4 ∈ {0, 1}
#       x5 ∈ {0, 1}
#       x6 ∈ {0, 1}
#       x7 ∈ {0, 1}
#       x8 ∈ {0, 1}
#
# === Solução para o Exemplo (Mochila) ===
# Status: Optimal
# Capacidade utilizada: 4830 g de 5000 g
# Utilidade total: 41
#
# Itens escolhidos:
#   Barra de cereal (utilidade = 6, peso = 200 g)
#   Casaco (utilidade = 7, peso = 400 g)
#   Tênis (utilidade = 3, peso = 400 g)
#   Celular (utilidade = 2, peso = 100 g)
#   Protetor solar (utilidade = 5, peso = 200 g)
#   Protetor labial (utilidade = 2, peso = 30 g)
#   Garrafas de oxigênio (utilidade = 10, peso = 3000 g)
#   Máquina fotográfica (utilidade = 6, peso = 500 g)

# %%
objetos = [
    "Binóculo",
    "Lanterna",
    "Kit de primeiros socorros",
    "Garrafa térmica",
    "Câmera HD",
    "Caderno de anotações",
    "GPS portátil",
    "Barraca leve",
    "Saco de dormir",
    "Cordas resistentes",
    "Ferramenta multiuso",
    "Tablet",
    "Rádio comunicador",
    "Protetor solar",
    "Bastão de caminhada",
]

utilidade = [5, 4, 1, 7, 9, 3, 8, 6, 7, 6, 5, 4, 6, 2, 3]
peso_gramas = [500, 300, 800, 900, 1200, 200,
               600, 1500, 1200, 700, 400, 600, 500, 100, 300]
capacidade_total = 6000  # 5 kg em gramas

solver = KnapsackSolver(utilidade, peso_gramas, capacidade_total)
res = solver.solve()
solver.print_model_equations()

print("\n=== Solução para o Exemplo (Mochila) ===")
print(f"Status: {res['status']}")
print(f"Capacidade utilizada: {res['total_weight']} g de {capacidade_total} g")
print(f"Utilidade total: {res['total_value']}")

print("\nItens escolhidos:")
for i in res['selected_items']:
    print(
        f"  {objetos[i]} (utilidade = {utilidade[i]}, peso = {peso_gramas[i]} g)")
# Out:
# Função objetivo:
# max z = 5·x0 + 4·x1 + 1·x2 + 7·x3 + 9·x4 + 3·x5 + 8·x6 + 6·x7 + 7·x8 + 6·x9 + 5·x10 + 4·x11 + 6·x12 + 2·x13 + 3·x14
#
# Restrição de capacidade:
#       500·x0 + 300·x1 + 800·x2 + 900·x3 + 1200·x4 + 200·x5 + 600·x6 + 1500·x7 + 1200·x8 + 700·x9 + 400·x10 + 600·x11 + 500·x12 + 100·x13 + 300·x14 ≤ 6000
#
# Variáveis de decisão:
#       x0 ∈ {0, 1}
#       x1 ∈ {0, 1}
#       x2 ∈ {0, 1}
#       x3 ∈ {0, 1}
#       x4 ∈ {0, 1}
#       x5 ∈ {0, 1}
#       x6 ∈ {0, 1}
#       x7 ∈ {0, 1}
#       x8 ∈ {0, 1}
#       x9 ∈ {0, 1}
#       x10 ∈ {0, 1}
#       x11 ∈ {0, 1}
#       x12 ∈ {0, 1}
#       x13 ∈ {0, 1}
#       x14 ∈ {0, 1}
#
# === Solução para o Exemplo (Mochila) ===
# Status: Optimal
# Capacidade utilizada: 6000 g de 6000 g
# Utilidade total: 59
#
# Itens escolhidos:
#   Binóculo (utilidade = 5, peso = 500 g)
#   Lanterna (utilidade = 4, peso = 300 g)
#   Garrafa térmica (utilidade = 7, peso = 900 g)
#   Câmera HD (utilidade = 9, peso = 1200 g)
#   Caderno de anotações (utilidade = 3, peso = 200 g)
#   GPS portátil (utilidade = 8, peso = 600 g)
#   Cordas resistentes (utilidade = 6, peso = 700 g)
#   Ferramenta multiuso (utilidade = 5, peso = 400 g)
#   Tablet (utilidade = 4, peso = 600 g)
#   Rádio comunicador (utilidade = 6, peso = 500 g)
#   Protetor solar (utilidade = 2, peso = 100 g)

# %%
objetos = [
    "Binóculo",
    "Lanterna",
    "Kit de primeiros socorros",
    "Garrafa térmica",
    "Câmera HD",
    "Caderno de anotações",
    "GPS portátil",
    "Barraca leve",
    "Saco de dormir",
    "Cordas resistentes",
    "Ferramenta multiuso",
    "Tablet",
    "Rádio comunicador",
    "Protetor solar",
    "Bastão de caminhada",
    "Mapa topográfico",
    "Isqueiro à prova d’água",
    "Livro de campo",
    "Inversor de energia",
    "Carregador solar",
    "Papel alumínio",
    "Canivete",
    "Par de meias térmicas",
    "Capa de chuva",
    "Filtro portátil de água",
    "Cinto utilitário",
    "Repelente",
    "Colchonete inflável",
    "Óculos de sol",
    "Kit de costura",
]

utilidade = [
    5, 4, 1, 7, 9, 3, 8, 6, 7, 6, 5, 4, 6, 2, 3,
    3, 2, 2, 4, 5, 1, 3, 2, 3, 5, 2, 2, 4, 2, 1
]

peso_gramas = [
    500, 300, 800, 900, 1200, 200, 600, 1500, 1200, 700, 400, 600,
    500, 100, 300, 250, 150, 350, 800, 400, 50, 250, 200, 300,
    600, 150, 120, 900, 180, 90
]

capacidade_total = 6000  # 6kg



solver = KnapsackSolver(utilidade, peso_gramas, capacidade_total)
res = solver.solve()
solver.print_model_equations()

print("\n=== Solução para o Exemplo (Mochila) ===")
print(f"Status: {res['status']}")
print(f"Capacidade utilizada: {res['total_weight']} g de {capacidade_total} g")
print(f"Utilidade total: {res['total_value']}")

print("\nItens escolhidos:")
for i in res['selected_items']:
    print(
        f"  {objetos[i]} (utilidade = {utilidade[i]}, peso = {peso_gramas[i]} g)")
# Out:
# Função objetivo:
# max z = 5·x0 + 4·x1 + 1·x2 + 7·x3 + 9·x4 + 3·x5 + 8·x6 + 6·x7 + 7·x8 + 6·x9 + 5·x10 + 4·x11 + 6·x12 + 2·x13 + 3·x14 + 3·x15 + 2·x16 + 2·x17 + 4·x18 + 5·x19 + 1·x20 + 3·x21 + 2·x22 + 3·x23 + 5·x24 + 2·x25 + 2·x26 + 4·x27 + 2·x28 + 1·x29
#
# Restrição de capacidade:
#       500·x0 + 300·x1 + 800·x2 + 900·x3 + 1200·x4 + 200·x5 + 600·x6 + 1500·x7 + 1200·x8 + 700·x9 + 400·x10 + 600·x11 + 500·x12 + 100·x13 + 300·x14 + 250·x15 + 150·x16 + 350·x17 + 800·x18 + 400·x19 + 50·x20 + 250·x21 + 200·x22 + 300·x23 + 600·x24 + 150·x25 + 120·x26 + 900·x27 + 180·x28 + 90·x29 ≤ 6000
#
# Variáveis de decisão:
#       x0 ∈ {0, 1}
#       x1 ∈ {0, 1}
#       x2 ∈ {0, 1}
#       x3 ∈ {0, 1}
#       x4 ∈ {0, 1}
#       x5 ∈ {0, 1}
#       x6 ∈ {0, 1}
#       x7 ∈ {0, 1}
#       x8 ∈ {0, 1}
#       x9 ∈ {0, 1}
#       x10 ∈ {0, 1}
#       x11 ∈ {0, 1}
#       x12 ∈ {0, 1}
#       x13 ∈ {0, 1}
#       x14 ∈ {0, 1}
#       x15 ∈ {0, 1}
#       x16 ∈ {0, 1}
#       x17 ∈ {0, 1}
#       x18 ∈ {0, 1}
#       x19 ∈ {0, 1}
#       x20 ∈ {0, 1}
#       x21 ∈ {0, 1}
#       x22 ∈ {0, 1}
#       x23 ∈ {0, 1}
#       x24 ∈ {0, 1}
#       x25 ∈ {0, 1}
#       x26 ∈ {0, 1}
#       x27 ∈ {0, 1}
#       x28 ∈ {0, 1}
#       x29 ∈ {0, 1}
#
# === Solução para o Exemplo (Mochila) ===
# Status: Optimal
# Capacidade utilizada: 5940 g de 6000 g
# Utilidade total: 69
#
# Itens escolhidos:
#   Binóculo (utilidade = 5, peso = 500 g)
#   Lanterna (utilidade = 4, peso = 300 g)
#   Garrafa térmica (utilidade = 7, peso = 900 g)
#   Caderno de anotações (utilidade = 3, peso = 200 g)
#   GPS portátil (utilidade = 8, peso = 600 g)
#   Ferramenta multiuso (utilidade = 5, peso = 400 g)
#   Rádio comunicador (utilidade = 6, peso = 500 g)
#   Protetor solar (utilidade = 2, peso = 100 g)
#   Bastão de caminhada (utilidade = 3, peso = 300 g)
#   Mapa topográfico (utilidade = 3, peso = 250 g)
#   Isqueiro à prova d’água (utilidade = 2, peso = 150 g)
#   Carregador solar (utilidade = 5, peso = 400 g)
#   Papel alumínio (utilidade = 1, peso = 50 g)
#   Canivete (utilidade = 3, peso = 250 g)
#   Par de meias térmicas (utilidade = 2, peso = 200 g)
#   Capa de chuva (utilidade = 3, peso = 300 g)
#   Cinto utilitário (utilidade = 2, peso = 150 g)
#   Repelente (utilidade = 2, peso = 120 g)
#   Óculos de sol (utilidade = 2, peso = 180 g)
#   Kit de costura (utilidade = 1, peso = 90 g)
